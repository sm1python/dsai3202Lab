# %% [markdown]
# # Maze Visualization Demo
#
# This notebook demonstrates the visualization capabilities of the maze runner game using the visualization utilities from the project.

# %%
import sys
import pygame
import time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Import our maze game modules
from src.maze import create_maze
from src.visualization import visualize_maze, JupyterExplorer
from src.enhanced_explorer import Explorer
from src.constants import WINDOW_SIZE
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Initialize Pygame for Jupyter
#
# We need to initialize Pygame in a way that works with Jupyter notebooks.

# %%
#pip install pygame

# %%
# Initialize Pygame
pygame.init()
screen = pygame.display.set_mode((WINDOW_SIZE, WINDOW_SIZE))
pygame.display.set_caption("Maze Explorer - Jupyter Visualization")

# %% [markdown]
# ## Create and Visualize a Random Maze
#
# Let's create a random maze and visualize it using the visualization utilities.

# %%
# Create and visualize a random maze
maze = create_maze(30, 30, "static")
visualize_maze(maze, screen)

# %% [markdown]
# ## Animated Maze Solving
#
# Let's use the JupyterExplorer to solve the maze with animation.

# %%
# Create maze and explorer
maze = create_maze(30, 30, "static")
explorer = JupyterExplorer(maze, screen)

# Run the explorer
time_taken, moves = explorer.solve()
print(f"Maze solved in {time_taken:.2f} seconds")
print(f"Number of moves: {len(moves)}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 explorer = JupyterExplorer(maze, screen)
#       5 # Run the explorer
# ----> 6 time_taken, moves = explorer.solve()
#       7 print(f"Maze solved in {time_taken:.2f} seconds")
#       8 print(f"Number of moves: {len(moves)}")
#
# File ~/dsai3202Lab/src/explorer.py:195, in Explorer.solve(self)
#     193 self.turn_left()
#     194 if self.can_move_forward():
# --> 195     self.move_forward()
#     196     visited.add((self.x, self.y))
#     197 else:
#     198     # If we can't move left, turn around
#
# File ~/dsai3202Lab/src/explorer.py:57, in Explorer.move_forward(self)
#      55 self.move_history.append(current_move)
#      56 if self.visualize:
# ---> 57     self.draw_state()
#
# File ~/dsai3202Lab/src/visualization.py:108, in JupyterExplorer.draw_state(self)
#     105 time.sleep(0.1)
#     107 # Clear the output for the next frame
# --> 108 clear_output(wait=True)
#
# File ~/anaconda3/lib/python3.12/site-packages/IPython/core/display_functions.py:386, in clear_output(wait)
#     384 from IPython.core.interactiveshell import InteractiveShell
#     385 if InteractiveShell.initialized():
# --> 386     InteractiveShell.instance().display_pub.clear_output(wait)
#     387 else:
#     388     print('\033[2K\r', end='')
#
# File ~/anaconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py:148, in ZMQDisplayPublisher.clear_output(self, wait)
#     137 """Clear output associated with the current execution (cell).
#     138
#     139 Parameters
#    (...)
#     145
#     146 """
#     147 content = dict(wait=wait)
# --> 148 self._flush_streams()
#     149 assert self.session is not None
#     150 msg = self.session.msg("clear_output", json_clean(content), parent=self.parent_header)
#
# File ~/anaconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~/anaconda3/lib/python3.12/site-packages/ipykernel/iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File ~/anaconda3/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/anaconda3/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Compare Different Maze Types
#
# Let's compare the visualization of random and static mazes.

# %%
# Create and visualize a random maze
random_maze = create_maze(30, 30, "random")
print("Random Maze:")
visualize_maze(random_maze, screen)

# Create and visualize a static maze
static_maze = create_maze(30, 30, "static")
print("Static Maze:")
visualize_maze(static_maze, screen)
# Out:
# Random Maze:
# Static Maze:

# %% [markdown]
# ## Performance Analysis
#
# Let's analyze the performance of the automated explorer on different maze types.

# %%
def run_exploration(maze_type, width, height):
    maze = create_maze(width, height, maze_type)
    explorer = Explorer(maze, visualize=False)
    start_time = time.time()
    time_taken, moves = explorer.solve()
    return {
        'maze_type': maze_type,
        'time_taken': time_taken,
        'moves': len(moves),
        'moves_per_second': len(moves) / time_taken
    }

# Run multiple explorations
results = []
for maze_type in ['random', 'static']:
    for _ in range(3):  # Run each type 3 times
        result = run_exploration(maze_type, 30, 30)
        results.append(result)
print("Simulation Done")
# Display results
df = pd.DataFrame(results)
print("Exploration Results:")
print(df.groupby('maze_type').mean())
